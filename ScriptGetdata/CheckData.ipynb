# %%
# read csv file and print out the data
import pandas as pd
import os

# read csv file
def get_year_data(file_path):
    data = pd.read_csv(file_path)
    # get unique year
    years = data["Year"].unique()
    # get missing years: 2000-2024
    missing_years = [str(year) for year in range(2000, 2025) if year not in years]

    # get type from file name between _ and .csv
    file_name = file_path.split("/")[-1]
    base_name = file_name.rsplit('_', 1)[0]
    type = file_name.split('_')[-1].split(".")[0]

    # convert to dataframe:
    row = {"Name": base_name}
    for year in years:
        row[str(year)] = type
    for year in missing_years:
        row[year] = "Missing"
    result_df = pd.DataFrame([row])

    # sort columns
    result_df = result_df[["Name"] + [str(year) for year in range(2000, 2025)]]

    return result_df

# list of csv files
file_list = os.listdir("../Data/CleanData/")
file_paths = ["../Data/CleanData/" + file for file in file_list]

# %%
get_year_data(file_paths[10])
# Out:
#        Name     2000     2001     2002     2003     2004     2005     2006  \
# 0  Botulism  Missing  Missing  Missing  Missing  Missing  Missing  Missing
#
#       2007     2008  ... 2015 2016 2017 2018 2019 2020 2021 2022 2023 2024
# 0  Missing  Missing  ...  mcd  mcd  mcd  mcd  mcd  mcd  mcd  mcd  mcd  mcd
#
# [1 rows x 26 columns]

# %%
import traceback

# analysis all files with error handling
result = pd.DataFrame()
for file_path in file_paths:
  try:
    df_row = get_year_data(file_path)
    result = pd.concat([result, df_row], ignore_index=True)
  except Exception as e:
    print(f"Error processing '{file_path}': {e}")
    traceback.print_exc()

# write to csv with error handling
try:
  result.to_csv("../Data/GetData.csv", index=False)
  print(f"Saved result to ../Data/GetData.csv, rows={len(result)}")
except Exception as e:
  print(f"Error writing CSV: {e}")
  traceback.print_exc()
# Out:
# Error processing '../Data/CleanData/Anthrax_rate.csv': No columns to parse from file
# Error processing '../Data/CleanData/Avian Influenza_rate.csv': No columns to parse from file
# Error processing '../Data/CleanData/Botulism_rate.csv': No columns to parse from file
# Error processing '../Data/CleanData/Brucellosis_rate.csv': No columns to parse from file
# Error processing '../Data/CleanData/Chancroid_rate.csv': No columns to parse from file
# Error processing '../Data/CleanData/Chickenpox_rate.csv': No columns to parse from file
# Traceback (most recent call last):
#   File "C:\Users\dell\AppData\Local\Temp/ipykernel_24380/1587361920.py", line 7, in <module>
#     df_row = get_year_data(file_path)
#   File "C:\Users\dell\AppData\Local\Temp/ipykernel_24380/1014522285.py", line 7, in get_year_data
#     data = pd.read_csv(file_path)
#   File "c:\Users\dell\anaconda3\lib\site-packages\pandas\util\_decorators.py", line 311, in wrapper
#     return func(*args, **kwargs)
#   File "c:\Users\dell\anaconda3\lib\site-packages\pandas\io\parsers\readers.py", line 586, in read_csv
#     return _read(filepath_or_buffer, kwds)
#   File "c:\Users\dell\anaconda3\lib\site-packages\pandas\io\parsers\readers.py", line 482, in _read
#     parser = TextFileReader(filepath_or_buffer, **kwds)
#   File "c:\Users\dell\anaconda3\lib\site-packages\pandas\io\parsers\readers.py", line 811, in __init__
#     self._engine = self._make_engine(self.engine)
#   File "c:\Users\dell\anaconda3\lib\site-packages\pandas\io\parsers\readers.py", line 1040, in _make_engine
#     return mapping[engine](self.f, **self.options)  # type: ignore[call-arg]
#   File "c:\Users\dell\anaconda3\lib\site-packages\pandas\io\parsers\c_parser_wrapper.py", line 69, in __init__
#     self._reader = parsers.TextReader(self.handles.handle, **kwds)
#   File "pandas\_libs\parsers.pyx", line 549, in pandas._libs.parsers.TextReader.__cinit__
# pandas.errors.EmptyDataError: No columns to parse from file
# Traceback (most recent call last):
#   File "C:\Users\dell\AppData\Local\Temp/ipykernel_24380/1587361920.py", line 7, in <module>
#     df_row = get_year_data(file_path)
#   File "C:\Users\dell\AppData\Local\Temp/ipykernel_24380/1014522285.py", line 7, in get_year_data
#     data = pd.read_csv(file_path)
#   File "c:\Users\dell\anaconda3\lib\site-packages\pandas\util\_decorators.py", line 311, in wrapper
#     return func(*args, **kwargs)
#   File "c:\Users\dell\anaconda3\lib\site-packages\pandas\io\parsers\readers.py", line 586, in read_csv
#     return _read(filepath_or_buffer, kwds)
#   File "c:\Users\dell\anaconda3\lib\site-packages\pandas\io\parsers\readers.py", line 482, in _read
#     parser = TextFileReader(filepath_or_buffer, **kwds)
#   File "c:\Users\dell\anaconda3\lib\site-packages\pandas\io\parsers\readers.py", line 811, in __init__
#     self._engine = self._make_engine(self.engine)
#   File "c:\Users\dell\anaconda3\lib\site-packages\pandas\io\parsers\readers.py", line 1040, in _make_engine
#     return mapping[engine](self.f, **self.options)  # type: ignore[call-arg]
#   File "c:\Users\dell\anaconda3\lib\site-packages\pandas\io\parsers\c_parser_wrapper.py", line 69, in __init__
#     self._reader = parsers.TextReader(self.handles.handle, **kwds)
#   File "pandas\_libs\parsers.pyx", line 549, in pandas._libs.parsers.TextReader.__cinit__
# pandas.errors.EmptyDataError: No columns to parse from file
# Traceback (most recent call last):
#   File "C:\Users\dell\AppData\Local\Temp/ipykernel_24380/1587361920.py", line 7, in <module>
#     df_row = get_year_data(file_path)
#   File "C:\Users\dell\AppData\Local\Temp/ipykernel_24380/1014522285.py", line 7, in get_year_data
#     data = pd.read_csv(file_path)
#   File "c:\Users\dell\anaconda3\lib\site-packages\pandas\util\_decorators.py", line 311, in wrapper
#     return func(*args, **kwargs)
#   File "c:\Users\dell\anaconda3\lib\site-packages\pandas\io\parsers\readers.py", line 586, in read_csv
#     return _read(filepath_or_buffer, kwds)
#   File "c:\Users\dell\anaconda3\lib\site-packages\pandas\io\parsers\readers.py", line 482, in _read
#     parser = TextFileReader(filepath_or_buffer, **kwds)
#   File "c:\Users\dell\anaconda3\lib\site-packages\pandas\io\parsers\readers.py", line 811, in __init__
#     self._engine = self._make_engine(self.engine)
#   File "c:\Users\dell\anaconda3\lib\site-packages\pandas\io\parsers\readers.py", line 1040, in _make_engine
#     return mapping[engine](self.f, **self.options)  # type: ignore[call-arg]
#   File "c:\Users\dell\anaconda3\lib\site-packages\pandas\io\parsers\c_parser_wrapper.py", line 69, in __init__
#     self._reader = parsers.TextReader(self.handles.handle, **kwds)
#   File "pandas\_libs\parsers.pyx", line 549, in pandas._libs.parsers.TextReader.__cinit__
# pandas.errors.EmptyDataError: No columns to parse from file
# Traceback (most recent call last):
#   File "C:\Users\dell\AppData\Local\Temp/ipykernel_24380/1587361920.py", line 7, in <module>
#     df_row = get_year_data(file_path)
#   File "C:\Users\dell\AppData\Local\Temp/ipykernel_24380/1014522285.py", line 7, in get_year_data
#     data = pd.read_csv(file_path)
#   File "c:\Users\dell\anaconda3\lib\site-packages\pandas\util\_decorators.py", line 311, in wrapper
#     return func(*args, **kwargs)
#   File "c:\Users\dell\anaconda3\lib\site-packages\pandas\io\parsers\readers.py", line 586, in read_csv
#     return _read(filepath_or_buffer, kwds)
#   File "c:\Users\dell\anaconda3\lib\site-packages\pandas\io\parsers\readers.py", line 482, in _read
#     parser = TextFileReader(filepath_or_buffer, **kwds)
#   File "c:\Users\dell\anaconda3\lib\site-packages\pandas\io\parsers\readers.py", line 811, in __init__
#     self._engine = self._make_engine(self.engine)
#   File "c:\Users\dell\anaconda3\lib\site-packages\pandas\io\parsers\readers.py", line 1040, in _make_engine
#     return mapping[engine](self.f, **self.options)  # type: ignore[call-arg]
#   File "c:\Users\dell\anaconda3\lib\site-packages\pandas\io\parsers\c_parser_wrapper.py", line 69, in __init__
#     self._reader = parsers.TextReader(self.handles.handle, **kwds)
#   File "pandas\_libs\parsers.pyx", line 549, in pandas._libs.parsers.TextReader.__cinit__
# pandas.errors.EmptyDataError: No columns to parse from file
# Traceback (most recent call last):
#   File "C:\Users\dell\AppData\Local\Temp/ipykernel_24380/1587361920.py", line 7, in <module>
#     df_row = get_year_data(file_path)
#   File "C:\Users\dell\AppData\Local\Temp/ipykernel_24380/1014522285.py", line 7, in get_year_data
#     data = pd.read_csv(file_path)
#   File "c:\Users\dell\anaconda3\lib\site-packages\pandas\util\_decorators.py", line 311, in wrapper
#     return func(*args, **kwargs)
#   File "c:\Users\dell\anaconda3\lib\site-packages\pandas\io\parsers\readers.py", line 586, in read_csv
#     return _read(filepath_or_buffer, kwds)
#   File "c:\Users\dell\anaconda3\lib\site-packages\pandas\io\parsers\readers.py", line 482, in _read
#     parser = TextFileReader(filepath_or_buffer, **kwds)
#   File "c:\Users\dell\anaconda3\lib\site-packages\pandas\io\parsers\readers.py", line 811, in __init__
#     self._engine = self._make_engine(self.engine)
#   File "c:\Users\dell\anaconda3\lib\site-packages\pandas\io\parsers\readers.py", line 1040, in _make_engine
#     return mapping[engine](self.f, **self.options)  # type: ignore[call-arg]
#   File "c:\Users\dell\anaconda3\lib\site-packages\pandas\io\parsers\c_parser_wrapper.py", line 69, in __init__
#     self._reader = parsers.TextReader(self.handles.handle, **kwds)
#   File "pandas\_libs\parsers.pyx", line 549, in pandas._libs.parsers.TextReader.__cinit__
# pandas.errors.EmptyDataError: No columns to parse from file
# Traceback (most recent call last):
#   File "C:\Users\dell\AppData\Local\Temp/ipykernel_24380/1587361920.py", line 7, in <module>
#     df_row = get_year_data(file_path)
#   File "C:\Users\dell\AppData\Local\Temp/ipykernel_24380/1014522285.py", line 7, in get_year_data
#     data = pd.read_csv(file_path)
#   File "c:\Users\dell\anaconda3\lib\site-packages\pandas\util\_decorators.py", line 311, in wrapper
#     return func(*args, **kwargs)
#   File "c:\Users\dell\anaconda3\lib\site-packages\pandas\io\parsers\readers.py", line 586, in read_csv
#     return _read(filepath_or_buffer, kwds)
#   File "c:\Users\dell\anaconda3\lib\site-packages\pandas\io\parsers\readers.py", line 482, in _read
#     parser = TextFileReader(filepath_or_buffer, **kwds)
#   File "c:\Users\dell\anaconda3\lib\site-packages\pandas\io\parsers\readers.py", line 811, in __init__
#     self._engine = self._make_engine(self.engine)
#   File "c:\Users\dell\anaconda3\lib\site-packages\pandas\io\parsers\readers.py", line 1040, in _make_engine
#     return mapping[engine](self.f, **self.options)  # type: ignore[call-arg]
#   File "c:\Users\dell\anaconda3\lib\site-packages\pandas\io\parsers\c_parser_wrapper.py", line 69, in __init__
#     self._reader = parsers.TextReader(self.handles.handle, **kwds)
#   File "pandas\_libs\parsers.pyx", line 549, in pandas._libs.parsers.TextReader.__cinit__
# pandas.errors.EmptyDataError: No columns to parse from file
# Traceback (most recent call last):
#   File "C:\Users\dell\AppData\Local\Temp/ipykernel_24380/1587361920.py", line 7, in <module>
#     df_row = get_year_data(file_path)
#   File "C:\Users\dell\AppData\Local\Temp/ipykernel_24380/1014522285.py", line 7, in get_year_data
#     data = pd.read_csv(file_path)
#   File "c:\Users\dell\anaconda3\lib\site-packages\pandas\util\_decorators.py", line 311, in wrapper
#     return func(*args, **kwargs)
#   File "c:\Users\dell\anaconda3\lib\site-packages\pandas\io\parsers\readers.py", line 586, in read_csv
#     return _read(filepath_or_buffer, kwds)
#   File "c:\Users\dell\anaconda3\lib\site-packages\pandas\io\parsers\readers.py", line 482, in _read
#     parser = TextFileReader(filepath_or_buffer, **kwds)
#   File "c:\Users\dell\anaconda3\lib\site-packages\pandas\io\parsers\readers.py", line 811, in __init__
#     self._engine = self._make_engine(self.engine)
#   File "c:\Users\dell\anaconda3\lib\site-packages\pandas\io\parsers\readers.py", line 1040, in _make_engine
#     return mapping[engine](self.f, **self.options)  # type: ignore[call-arg]
#   File "c:\Users\dell\anaconda3\lib\site-packages\pandas\io\parsers\c_parser_wrapper.py", line 69, in __init__
#     self._reader = parsers.TextReader(self.handles.handle, **kwds)
#   File "pandas\_libs\parsers.pyx", line 549, in pandas._libs.parsers.TextReader.__cinit__
# pandas.errors.EmptyDataError: No columns to parse from file
# Traceback (most recent call last):
#   File "C:\Users\dell\AppData\Local\Temp/ipykernel_24380/1587361920.py", line 7, in <module>
#     df_row = get_year_data(file_path)
#   File "C:\Users\dell\AppData\Local\Temp/ipykernel_24380/1014522285.py", line 7, in get_year_data
#     data = pd.read_csv(file_path)
#   File "c:\Users\dell\anaconda3\lib\site-packages\pandas\util\_decorators.py", line 311, in wrapper
#     return func(*args, **kwargs)
#   File "c:\Users\dell\anaconda3\lib\site-packages\pandas\io\parsers\readers.py", line 586, in read_csv
#     return _read(filepath_or_buffer, kwds)
#   File "c:\Users\dell\anaconda3\lib\site-packages\pandas\io\parsers\readers.py", line 482, in _read
#     parser = TextFileReader(filepath_or_buffer, **kwds)
#   File "c:\Users\dell\anaconda3\lib\site-packages\pandas\io\parsers\readers.py", line 811, in __init__
#     self._engine = self._make_engine(self.engine)
#   File "c:\Users\dell\anaconda3\lib\site-packages\pandas\io\parsers\readers.py", line 1040, in _make_engine
#     return mapping[engine](self.f, **self.options)  # type: ignore[call-arg]
#   File "c:\Users\dell\anaconda3\lib\site-packages\pandas\io\parsers\c_parser_wrapper.py", line 69, in __init__
#     self._reader = parsers.TextReader(self.handles.handle, **kwds)
#   File "pandas\_libs\parsers.pyx", line 549, in pandas._libs.parsers.TextReader.__cinit__
# pandas.errors.EmptyDataError: No columns to parse from file
# Traceback (most recent call last):
#   File "C:\Users\dell\AppData\Local\Temp/ipykernel_24380/1587361920.py", line 7, in <module>
#     df_row = get_year_data(file_path)
#   File "C:\Users\dell\AppData\Local\Temp/ipykernel_24380/1014522285.py", line 7, in get_year_data
#     data = pd.read_csv(file_path)
#   File "c:\Users\dell\anaconda3\lib\site-packages\pandas\util\_decorators.py", line 311, in wrapper
#     return func(*args, **kwargs)
#   File "c:\Users\dell\anaconda3\lib\site-packages\pandas\io\parsers\readers.py", line 586, in read_csv
#     return _read(filepath_or_buffer, kwds)
#   File "c:\Users\dell\anaconda3\lib\site-packages\pandas\io\parsers\readers.py", line 482, in _read
#     parser = TextFileReader(filepath_or_buffer, **kwds)
#   File "c:\Users\dell\anaconda3\lib\site-packages\pandas\io\parsers\readers.py", line 811, in __init__
#     self._engine = self._make_engine(self.engine)
#   File "c:\Users\dell\anaconda3\lib\site-packages\pandas\io\parsers\readers.py", line 1040, in _make_engine
#     return mapping[engine](self.f, **self.options)  # type: ignore[call-arg]
#   File "c:\Users\dell\anaconda3\lib\site-packages\pandas\io\parsers\c_parser_wrapper.py", line 69, in __init__
#     self._reader = parsers.TextReader(self.handles.handle, **kwds)
#   File "pandas\_libs\parsers.pyx", line 549, in pandas._libs.parsers.TextReader.__cinit__
# pandas.errors.EmptyDataError: No columns to parse from file
# Error processing '../Data/CleanData/Chikungunya_rate.csv': No columns to parse from file
# Error processing '../Data/CleanData/Cholera_rate.csv': No columns to parse from file
# Error processing '../Data/CleanData/Condyloma Acuminata_rate.csv': No columns to parse from file
# Error processing '../Data/CleanData/D.H.F.shock syndrome_rate.csv': No columns to parse from file
# Traceback (most recent call last):
#   File "C:\Users\dell\AppData\Local\Temp/ipykernel_24380/1587361920.py", line 7, in <module>
#     df_row = get_year_data(file_path)
#   File "C:\Users\dell\AppData\Local\Temp/ipykernel_24380/1014522285.py", line 7, in get_year_data
#     data = pd.read_csv(file_path)
#   File "c:\Users\dell\anaconda3\lib\site-packages\pandas\util\_decorators.py", line 311, in wrapper
#     return func(*args, **kwargs)
#   File "c:\Users\dell\anaconda3\lib\site-packages\pandas\io\parsers\readers.py", line 586, in read_csv
#     return _read(filepath_or_buffer, kwds)
#   File "c:\Users\dell\anaconda3\lib\site-packages\pandas\io\parsers\readers.py", line 482, in _read
#     parser = TextFileReader(filepath_or_buffer, **kwds)
#   File "c:\Users\dell\anaconda3\lib\site-packages\pandas\io\parsers\readers.py", line 811, in __init__
#     self._engine = self._make_engine(self.engine)
#   File "c:\Users\dell\anaconda3\lib\site-packages\pandas\io\parsers\readers.py", line 1040, in _make_engine
#     return mapping[engine](self.f, **self.options)  # type: ignore[call-arg]
#   File "c:\Users\dell\anaconda3\lib\site-packages\pandas\io\parsers\c_parser_wrapper.py", line 69, in __init__
#     self._reader = parsers.TextReader(self.handles.handle, **kwds)
#   File "pandas\_libs\parsers.pyx", line 549, in pandas._libs.parsers.TextReader.__cinit__
# pandas.errors.EmptyDataError: No columns to parse from file
# Traceback (most recent call last):
#   File "C:\Users\dell\AppData\Local\Temp/ipykernel_24380/1587361920.py", line 7, in <module>
#     df_row = get_year_data(file_path)
#   File "C:\Users\dell\AppData\Local\Temp/ipykernel_24380/1014522285.py", line 7, in get_year_data
#     data = pd.read_csv(file_path)
#   File "c:\Users\dell\anaconda3\lib\site-packages\pandas\util\_decorators.py", line 311, in wrapper
#     return func(*args, **kwargs)
#   File "c:\Users\dell\anaconda3\lib\site-packages\pandas\io\parsers\readers.py", line 586, in read_csv
#     return _read(filepath_or_buffer, kwds)
#   File "c:\Users\dell\anaconda3\lib\site-packages\pandas\io\parsers\readers.py", line 482, in _read
#     parser = TextFileReader(filepath_or_buffer, **kwds)
#   File "c:\Users\dell\anaconda3\lib\site-packages\pandas\io\parsers\readers.py", line 811, in __init__
#     self._engine = self._make_engine(self.engine)
#   File "c:\Users\dell\anaconda3\lib\site-packages\pandas\io\parsers\readers.py", line 1040, in _make_engine
#     return mapping[engine](self.f, **self.options)  # type: ignore[call-arg]
#   File "c:\Users\dell\anaconda3\lib\site-packages\pandas\io\parsers\c_parser_wrapper.py", line 69, in __init__
#     self._reader = parsers.TextReader(self.handles.handle, **kwds)
#   File "pandas\_libs\parsers.pyx", line 549, in pandas._libs.parsers.TextReader.__cinit__
# pandas.errors.EmptyDataError: No columns to parse from file
# Traceback (most recent call last):
#   File "C:\Users\dell\AppData\Local\Temp/ipykernel_24380/1587361920.py", line 7, in <module>
#     df_row = get_year_data(file_path)
#   File "C:\Users\dell\AppData\Local\Temp/ipykernel_24380/1014522285.py", line 7, in get_year_data
#     data = pd.read_csv(file_path)
#   File "c:\Users\dell\anaconda3\lib\site-packages\pandas\util\_decorators.py", line 311, in wrapper
#     return func(*args, **kwargs)
#   File "c:\Users\dell\anaconda3\lib\site-packages\pandas\io\parsers\readers.py", line 586, in read_csv
#     return _read(filepath_or_buffer, kwds)
#   File "c:\Users\dell\anaconda3\lib\site-packages\pandas\io\parsers\readers.py", line 482, in _read
#     parser = TextFileReader(filepath_or_buffer, **kwds)
#   File "c:\Users\dell\anaconda3\lib\site-packages\pandas\io\parsers\readers.py", line 811, in __init__
#     self._engine = self._make_engine(self.engine)
#   File "c:\Users\dell\anaconda3\lib\site-packages\pandas\io\parsers\readers.py", line 1040, in _make_engine
#     return mapping[engine](self.f, **self.options)  # type: ignore[call-arg]
#   File "c:\Users\dell\anaconda3\lib\site-packages\pandas\io\parsers\c_parser_wrapper.py", line 69, in __init__
#     self._reader = parsers.TextReader(self.handles.handle, **kwds)
#   File "pandas\_libs\parsers.pyx", line 549, in pandas._libs.parsers.TextReader.__cinit__
# pandas.errors.EmptyDataError: No columns to parse from file
# Traceback (most recent call last):
#   File "C:\Users\dell\AppData\Local\Temp/ipykernel_24380/1587361920.py", line 7, in <module>
#     df_row = get_year_data(file_path)
#   File "C:\Users\dell\AppData\Local\Temp/ipykernel_24380/1014522285.py", line 7, in get_year_data
#     data = pd.read_csv(file_path)
#   File "c:\Users\dell\anaconda3\lib\site-packages\pandas\util\_decorators.py", line 311, in wrapper
#     return func(*args, **kwargs)
#   File "c:\Users\dell\anaconda3\lib\site-packages\pandas\io\parsers\readers.py", line 586, in read_csv
#     return _read(filepath_or_buffer, kwds)
#   File "c:\Users\dell\anaconda3\lib\site-packages\pandas\io\parsers\readers.py", line 482, in _read
#     parser = TextFileReader(filepath_or_buffer, **kwds)
#   File "c:\Users\dell\anaconda3\lib\site-packages\pandas\io\parsers\readers.py", line 811, in __init__
#     self._engine = self._make_engine(self.engine)
#   File "c:\Users\dell\anaconda3\lib\site-packages\pandas\io\parsers\readers.py", line 1040, in _make_engine
#     return mapping[engine](self.f, **self.options)  # type: ignore[call-arg]
#   File "c:\Users\dell\anaconda3\lib\site-packages\pandas\io\parsers\c_parser_wrapper.py", line 69, in __init__
#     self._reader = parsers.TextReader(self.handles.handle, **kwds)
#   File "pandas\_libs\parsers.pyx", line 549, in pandas._libs.parsers.TextReader.__cinit__
# pandas.errors.EmptyDataError: No columns to parse from file
# Error processing '../Data/CleanData/D.H.F_rate.csv': No columns to parse from file
# Error processing '../Data/CleanData/Dengue fever_rate.csv': No columns to parse from file
# Error processing '../Data/CleanData/Diphtheria_rate.csv': No columns to parse from file
# Error processing '../Data/CleanData/Dysentery,Amoebic_rate.csv': No columns to parse from file
# Traceback (most recent call last):
#   File "C:\Users\dell\AppData\Local\Temp/ipykernel_24380/1587361920.py", line 7, in <module>
#     df_row = get_year_data(file_path)
#   File "C:\Users\dell\AppData\Local\Temp/ipykernel_24380/1014522285.py", line 7, in get_year_data
#     data = pd.read_csv(file_path)
#   File "c:\Users\dell\anaconda3\lib\site-packages\pandas\util\_decorators.py", line 311, in wrapper
#     return func(*args, **kwargs)
#   File "c:\Users\dell\anaconda3\lib\site-packages\pandas\io\parsers\readers.py", line 586, in read_csv
#     return _read(filepath_or_buffer, kwds)
#   File "c:\Users\dell\anaconda3\lib\site-packages\pandas\io\parsers\readers.py", line 482, in _read
#     parser = TextFileReader(filepath_or_buffer, **kwds)
#   File "c:\Users\dell\anaconda3\lib\site-packages\pandas\io\parsers\readers.py", line 811, in __init__
#     self._engine = self._make_engine(self.engine)
#   File "c:\Users\dell\anaconda3\lib\site-packages\pandas\io\parsers\readers.py", line 1040, in _make_engine
#     return mapping[engine](self.f, **self.options)  # type: ignore[call-arg]
#   File "c:\Users\dell\anaconda3\lib\site-packages\pandas\io\parsers\c_parser_wrapper.py", line 69, in __init__
#     self._reader = parsers.TextReader(self.handles.handle, **kwds)
#   File "pandas\_libs\parsers.pyx", line 549, in pandas._libs.parsers.TextReader.__cinit__
# pandas.errors.EmptyDataError: No columns to parse from file
# Traceback (most recent call last):
#   File "C:\Users\dell\AppData\Local\Temp/ipykernel_24380/1587361920.py", line 7, in <module>
#     df_row = get_year_data(file_path)
#   File "C:\Users\dell\AppData\Local\Temp/ipykernel_24380/1014522285.py", line 7, in get_year_data
#     data = pd.read_csv(file_path)
#   File "c:\Users\dell\anaconda3\lib\site-packages\pandas\util\_decorators.py", line 311, in wrapper
#     return func(*args, **kwargs)
#   File "c:\Users\dell\anaconda3\lib\site-packages\pandas\io\parsers\readers.py", line 586, in read_csv
#     return _read(filepath_or_buffer, kwds)
#   File "c:\Users\dell\anaconda3\lib\site-packages\pandas\io\parsers\readers.py", line 482, in _read
#     parser = TextFileReader(filepath_or_buffer, **kwds)
#   File "c:\Users\dell\anaconda3\lib\site-packages\pandas\io\parsers\readers.py", line 811, in __init__
#     self._engine = self._make_engine(self.engine)
#   File "c:\Users\dell\anaconda3\lib\site-packages\pandas\io\parsers\readers.py", line 1040, in _make_engine
#     return mapping[engine](self.f, **self.options)  # type: ignore[call-arg]
#   File "c:\Users\dell\anaconda3\lib\site-packages\pandas\io\parsers\c_parser_wrapper.py", line 69, in __init__
#     self._reader = parsers.TextReader(self.handles.handle, **kwds)
#   File "pandas\_libs\parsers.pyx", line 549, in pandas._libs.parsers.TextReader.__cinit__
# pandas.errors.EmptyDataError: No columns to parse from file
# Traceback (most recent call last):
#   File "C:\Users\dell\AppData\Local\Temp/ipykernel_24380/1587361920.py", line 7, in <module>
#     df_row = get_year_data(file_path)
#   File "C:\Users\dell\AppData\Local\Temp/ipykernel_24380/1014522285.py", line 7, in get_year_data
#     data = pd.read_csv(file_path)
#   File "c:\Users\dell\anaconda3\lib\site-packages\pandas\util\_decorators.py", line 311, in wrapper
#     return func(*args, **kwargs)
#   File "c:\Users\dell\anaconda3\lib\site-packages\pandas\io\parsers\readers.py", line 586, in read_csv
#     return _read(filepath_or_buffer, kwds)
#   File "c:\Users\dell\anaconda3\lib\site-packages\pandas\io\parsers\readers.py", line 482, in _read
#     parser = TextFileReader(filepath_or_buffer, **kwds)
#   File "c:\Users\dell\anaconda3\lib\site-packages\pandas\io\parsers\readers.py", line 811, in __init__
#     self._engine = self._make_engine(self.engine)
#   File "c:\Users\dell\anaconda3\lib\site-packages\pandas\io\parsers\readers.py", line 1040, in _make_engine
#     return mapping[engine](self.f, **self.options)  # type: ignore[call-arg]
#   File "c:\Users\dell\anaconda3\lib\site-packages\pandas\io\parsers\c_parser_wrapper.py", line 69, in __init__
#     self._reader = parsers.TextReader(self.handles.handle, **kwds)
#   File "pandas\_libs\parsers.pyx", line 549, in pandas._libs.parsers.TextReader.__cinit__
# pandas.errors.EmptyDataError: No columns to parse from file
# Traceback (most recent call last):
#   File "C:\Users\dell\AppData\Local\Temp/ipykernel_24380/1587361920.py", line 7, in <module>
#     df_row = get_year_data(file_path)
#   File "C:\Users\dell\AppData\Local\Temp/ipykernel_24380/1014522285.py", line 7, in get_year_data
#     data = pd.read_csv(file_path)
#   File "c:\Users\dell\anaconda3\lib\site-packages\pandas\util\_decorators.py", line 311, in wrapper
#     return func(*args, **kwargs)
#   File "c:\Users\dell\anaconda3\lib\site-packages\pandas\io\parsers\readers.py", line 586, in read_csv
#     return _read(filepath_or_buffer, kwds)
#   File "c:\Users\dell\anaconda3\lib\site-packages\pandas\io\parsers\readers.py", line 482, in _read
#     parser = TextFileReader(filepath_or_buffer, **kwds)
#   File "c:\Users\dell\anaconda3\lib\site-packages\pandas\io\parsers\readers.py", line 811, in __init__
#     self._engine = self._make_engine(self.engine)
#   File "c:\Users\dell\anaconda3\lib\site-packages\pandas\io\parsers\readers.py", line 1040, in _make_engine
#     return mapping[engine](self.f, **self.options)  # type: ignore[call-arg]
#   File "c:\Users\dell\anaconda3\lib\site-packages\pandas\io\parsers\c_parser_wrapper.py", line 69, in __init__
#     self._reader = parsers.TextReader(self.handles.handle, **kwds)
#   File "pandas\_libs\parsers.pyx", line 549, in pandas._libs.parsers.TextReader.__cinit__
# pandas.errors.EmptyDataError: No columns to parse from file
# Error processing '../Data/CleanData/Dysentery,Bacillary_rate.csv': No columns to parse from file
# Error processing '../Data/CleanData/Encephalitis uns_rate.csv': No columns to parse from file
# Error processing '../Data/CleanData/Enterovirus Fever_rate.csv': No columns to parse from file
# Error processing '../Data/CleanData/Eosinophilic Meningitis_rate.csv': No columns to parse from file
# Error processing '../Data/CleanData/Filariasis_rate.csv': No columns to parse from file
# Traceback (most recent call last):
#   File "C:\Users\dell\AppData\Local\Temp/ipykernel_24380/1587361920.py", line 7, in <module>
#     df_row = get_year_data(file_path)
#   File "C:\Users\dell\AppData\Local\Temp/ipykernel_24380/1014522285.py", line 7, in get_year_data
#     data = pd.read_csv(file_path)
#   File "c:\Users\dell\anaconda3\lib\site-packages\pandas\util\_decorators.py", line 311, in wrapper
#     return func(*args, **kwargs)
#   File "c:\Users\dell\anaconda3\lib\site-packages\pandas\io\parsers\readers.py", line 586, in read_csv
#     return _read(filepath_or_buffer, kwds)
#   File "c:\Users\dell\anaconda3\lib\site-packages\pandas\io\parsers\readers.py", line 482, in _read
#     parser = TextFileReader(filepath_or_buffer, **kwds)
#   File "c:\Users\dell\anaconda3\lib\site-packages\pandas\io\parsers\readers.py", line 811, in __init__
#     self._engine = self._make_engine(self.engine)
#   File "c:\Users\dell\anaconda3\lib\site-packages\pandas\io\parsers\readers.py", line 1040, in _make_engine
#     return mapping[engine](self.f, **self.options)  # type: ignore[call-arg]
#   File "c:\Users\dell\anaconda3\lib\site-packages\pandas\io\parsers\c_parser_wrapper.py", line 69, in __init__
#     self._reader = parsers.TextReader(self.handles.handle, **kwds)
#   File "pandas\_libs\parsers.pyx", line 549, in pandas._libs.parsers.TextReader.__cinit__
# pandas.errors.EmptyDataError: No columns to parse from file
# Traceback (most recent call last):
#   File "C:\Users\dell\AppData\Local\Temp/ipykernel_24380/1587361920.py", line 7, in <module>
#     df_row = get_year_data(file_path)
#   File "C:\Users\dell\AppData\Local\Temp/ipykernel_24380/1014522285.py", line 7, in get_year_data
#     data = pd.read_csv(file_path)
#   File "c:\Users\dell\anaconda3\lib\site-packages\pandas\util\_decorators.py", line 311, in wrapper
#     return func(*args, **kwargs)
#   File "c:\Users\dell\anaconda3\lib\site-packages\pandas\io\parsers\readers.py", line 586, in read_csv
#     return _read(filepath_or_buffer, kwds)
#   File "c:\Users\dell\anaconda3\lib\site-packages\pandas\io\parsers\readers.py", line 482, in _read
#     parser = TextFileReader(filepath_or_buffer, **kwds)
#   File "c:\Users\dell\anaconda3\lib\site-packages\pandas\io\parsers\readers.py", line 811, in __init__
#     self._engine = self._make_engine(self.engine)
#   File "c:\Users\dell\anaconda3\lib\site-packages\pandas\io\parsers\readers.py", line 1040, in _make_engine
#     return mapping[engine](self.f, **self.options)  # type: ignore[call-arg]
#   File "c:\Users\dell\anaconda3\lib\site-packages\pandas\io\parsers\c_parser_wrapper.py", line 69, in __init__
#     self._reader = parsers.TextReader(self.handles.handle, **kwds)
#   File "pandas\_libs\parsers.pyx", line 549, in pandas._libs.parsers.TextReader.__cinit__
# pandas.errors.EmptyDataError: No columns to parse from file
# Traceback (most recent call last):
#   File "C:\Users\dell\AppData\Local\Temp/ipykernel_24380/1587361920.py", line 7, in <module>
#     df_row = get_year_data(file_path)
#   File "C:\Users\dell\AppData\Local\Temp/ipykernel_24380/1014522285.py", line 7, in get_year_data
#     data = pd.read_csv(file_path)
#   File "c:\Users\dell\anaconda3\lib\site-packages\pandas\util\_decorators.py", line 311, in wrapper
#     return func(*args, **kwargs)
#   File "c:\Users\dell\anaconda3\lib\site-packages\pandas\io\parsers\readers.py", line 586, in read_csv
#     return _read(filepath_or_buffer, kwds)
#   File "c:\Users\dell\anaconda3\lib\site-packages\pandas\io\parsers\readers.py", line 482, in _read
#     parser = TextFileReader(filepath_or_buffer, **kwds)
#   File "c:\Users\dell\anaconda3\lib\site-packages\pandas\io\parsers\readers.py", line 811, in __init__
#     self._engine = self._make_engine(self.engine)
#   File "c:\Users\dell\anaconda3\lib\site-packages\pandas\io\parsers\readers.py", line 1040, in _make_engine
#     return mapping[engine](self.f, **self.options)  # type: ignore[call-arg]
#   File "c:\Users\dell\anaconda3\lib\site-packages\pandas\io\parsers\c_parser_wrapper.py", line 69, in __init__
#     self._reader = parsers.TextReader(self.handles.handle, **kwds)
#   File "pandas\_libs\parsers.pyx", line 549, in pandas._libs.parsers.TextReader.__cinit__
# pandas.errors.EmptyDataError: No columns to parse from file
# Error processing '../Data/CleanData/Food_Poisoning_rate.csv': No columns to parse from file
# Error processing '../Data/CleanData/Genital Herpes Simplex_rate.csv': No columns to parse from file
# Error processing '../Data/CleanData/Genital Molluscum Contagiosum_rate.csv': No columns to parse from file
# Error processing '../Data/CleanData/Gonorrhoea_rate.csv': No columns to parse from file
# Traceback (most recent call last):
#   File "C:\Users\dell\AppData\Local\Temp/ipykernel_24380/1587361920.py", line 7, in <module>
#     df_row = get_year_data(file_path)
#   File "C:\Users\dell\AppData\Local\Temp/ipykernel_24380/1014522285.py", line 7, in get_year_data
#     data = pd.read_csv(file_path)
#   File "c:\Users\dell\anaconda3\lib\site-packages\pandas\util\_decorators.py", line 311, in wrapper
#     return func(*args, **kwargs)
#   File "c:\Users\dell\anaconda3\lib\site-packages\pandas\io\parsers\readers.py", line 586, in read_csv
#     return _read(filepath_or_buffer, kwds)
#   File "c:\Users\dell\anaconda3\lib\site-packages\pandas\io\parsers\readers.py", line 482, in _read
#     parser = TextFileReader(filepath_or_buffer, **kwds)
#   File "c:\Users\dell\anaconda3\lib\site-packages\pandas\io\parsers\readers.py", line 811, in __init__
#     self._engine = self._make_engine(self.engine)
#   File "c:\Users\dell\anaconda3\lib\site-packages\pandas\io\parsers\readers.py", line 1040, in _make_engine
#     return mapping[engine](self.f, **self.options)  # type: ignore[call-arg]
#   File "c:\Users\dell\anaconda3\lib\site-packages\pandas\io\parsers\c_parser_wrapper.py", line 69, in __init__
#     self._reader = parsers.TextReader(self.handles.handle, **kwds)
#   File "pandas\_libs\parsers.pyx", line 549, in pandas._libs.parsers.TextReader.__cinit__
# pandas.errors.EmptyDataError: No columns to parse from file
# Traceback (most recent call last):
#   File "C:\Users\dell\AppData\Local\Temp/ipykernel_24380/1587361920.py", line 7, in <module>
#     df_row = get_year_data(file_path)
#   File "C:\Users\dell\AppData\Local\Temp/ipykernel_24380/1014522285.py", line 7, in get_year_data
#     data = pd.read_csv(file_path)
#   File "c:\Users\dell\anaconda3\lib\site-packages\pandas\util\_decorators.py", line 311, in wrapper
#     return func(*args, **kwargs)
#   File "c:\Users\dell\anaconda3\lib\site-packages\pandas\io\parsers\readers.py", line 586, in read_csv
#     return _read(filepath_or_buffer, kwds)
#   File "c:\Users\dell\anaconda3\lib\site-packages\pandas\io\parsers\readers.py", line 482, in _read
#     parser = TextFileReader(filepath_or_buffer, **kwds)
#   File "c:\Users\dell\anaconda3\lib\site-packages\pandas\io\parsers\readers.py", line 811, in __init__
#     self._engine = self._make_engine(self.engine)
#   File "c:\Users\dell\anaconda3\lib\site-packages\pandas\io\parsers\readers.py", line 1040, in _make_engine
#     return mapping[engine](self.f, **self.options)  # type: ignore[call-arg]
#   File "c:\Users\dell\anaconda3\lib\site-packages\pandas\io\parsers\c_parser_wrapper.py", line 69, in __init__
#     self._reader = parsers.TextReader(self.handles.handle, **kwds)
#   File "pandas\_libs\parsers.pyx", line 549, in pandas._libs.parsers.TextReader.__cinit__
# pandas.errors.EmptyDataError: No columns to parse from file
# Traceback (most recent call last):
#   File "C:\Users\dell\AppData\Local\Temp/ipykernel_24380/1587361920.py", line 7, in <module>
#     df_row = get_year_data(file_path)
#   File "C:\Users\dell\AppData\Local\Temp/ipykernel_24380/1014522285.py", line 7, in get_year_data
#     data = pd.read_csv(file_path)
#   File "c:\Users\dell\anaconda3\lib\site-packages\pandas\util\_decorators.py", line 311, in wrapper
#     return func(*args, **kwargs)
#   File "c:\Users\dell\anaconda3\lib\site-packages\pandas\io\parsers\readers.py", line 586, in read_csv
#     return _read(filepath_or_buffer, kwds)
#   File "c:\Users\dell\anaconda3\lib\site-packages\pandas\io\parsers\readers.py", line 482, in _read
#     parser = TextFileReader(filepath_or_buffer, **kwds)
#   File "c:\Users\dell\anaconda3\lib\site-packages\pandas\io\parsers\readers.py", line 811, in __init__
#     self._engine = self._make_engine(self.engine)
#   File "c:\Users\dell\anaconda3\lib\site-packages\pandas\io\parsers\readers.py", line 1040, in _make_engine
#     return mapping[engine](self.f, **self.options)  # type: ignore[call-arg]
#   File "c:\Users\dell\anaconda3\lib\site-packages\pandas\io\parsers\c_parser_wrapper.py", line 69, in __init__
#     self._reader = parsers.TextReader(self.handles.handle, **kwds)
#   File "pandas\_libs\parsers.pyx", line 549, in pandas._libs.parsers.TextReader.__cinit__
# pandas.errors.EmptyDataError: No columns to parse from file
# Traceback (most recent call last):
#   File "C:\Users\dell\AppData\Local\Temp/ipykernel_24380/1587361920.py", line 7, in <module>
#     df_row = get_year_data(file_path)
#   File "C:\Users\dell\AppData\Local\Temp/ipykernel_24380/1014522285.py", line 7, in get_year_data
#     data = pd.read_csv(file_path)
#   File "c:\Users\dell\anaconda3\lib\site-packages\pandas\util\_decorators.py", line 311, in wrapper
#     return func(*args, **kwargs)
#   File "c:\Users\dell\anaconda3\lib\site-packages\pandas\io\parsers\readers.py", line 586, in read_csv
#     return _read(filepath_or_buffer, kwds)
#   File "c:\Users\dell\anaconda3\lib\site-packages\pandas\io\parsers\readers.py", line 482, in _read
#     parser = TextFileReader(filepath_or_buffer, **kwds)
#   File "c:\Users\dell\anaconda3\lib\site-packages\pandas\io\parsers\readers.py", line 811, in __init__
#     self._engine = self._make_engine(self.engine)
#   File "c:\Users\dell\anaconda3\lib\site-packages\pandas\io\parsers\readers.py", line 1040, in _make_engine
#     return mapping[engine](self.f, **self.options)  # type: ignore[call-arg]
#   File "c:\Users\dell\anaconda3\lib\site-packages\pandas\io\parsers\c_parser_wrapper.py", line 69, in __init__
#     self._reader = parsers.TextReader(self.handles.handle, **kwds)
#   File "pandas\_libs\parsers.pyx", line 549, in pandas._libs.parsers.TextReader.__cinit__
# pandas.errors.EmptyDataError: No columns to parse from file
# Error processing '../Data/CleanData/HepatitisA_rate.csv': No columns to parse from file
# Error processing '../Data/CleanData/HepatitisB_rate.csv': No columns to parse from file
# Error processing '../Data/CleanData/HepatitisC_rate.csv': No columns to parse from file
# Error processing '../Data/CleanData/HepatitisD_rate.csv': No columns to parse from file
# Traceback (most recent call last):
#   File "C:\Users\dell\AppData\Local\Temp/ipykernel_24380/1587361920.py", line 7, in <module>
#     df_row = get_year_data(file_path)
#   File "C:\Users\dell\AppData\Local\Temp/ipykernel_24380/1014522285.py", line 7, in get_year_data
#     data = pd.read_csv(file_path)
#   File "c:\Users\dell\anaconda3\lib\site-packages\pandas\util\_decorators.py", line 311, in wrapper
#     return func(*args, **kwargs)
#   File "c:\Users\dell\anaconda3\lib\site-packages\pandas\io\parsers\readers.py", line 586, in read_csv
#     return _read(filepath_or_buffer, kwds)
#   File "c:\Users\dell\anaconda3\lib\site-packages\pandas\io\parsers\readers.py", line 482, in _read
#     parser = TextFileReader(filepath_or_buffer, **kwds)
#   File "c:\Users\dell\anaconda3\lib\site-packages\pandas\io\parsers\readers.py", line 811, in __init__
#     self._engine = self._make_engine(self.engine)
#   File "c:\Users\dell\anaconda3\lib\site-packages\pandas\io\parsers\readers.py", line 1040, in _make_engine
#     return mapping[engine](self.f, **self.options)  # type: ignore[call-arg]
#   File "c:\Users\dell\anaconda3\lib\site-packages\pandas\io\parsers\c_parser_wrapper.py", line 69, in __init__
#     self._reader = parsers.TextReader(self.handles.handle, **kwds)
#   File "pandas\_libs\parsers.pyx", line 549, in pandas._libs.parsers.TextReader.__cinit__
# pandas.errors.EmptyDataError: No columns to parse from file
# Traceback (most recent call last):
#   File "C:\Users\dell\AppData\Local\Temp/ipykernel_24380/1587361920.py", line 7, in <module>
#     df_row = get_year_data(file_path)
#   File "C:\Users\dell\AppData\Local\Temp/ipykernel_24380/1014522285.py", line 7, in get_year_data
#     data = pd.read_csv(file_path)
#   File "c:\Users\dell\anaconda3\lib\site-packages\pandas\util\_decorators.py", line 311, in wrapper
#     return func(*args, **kwargs)
#   File "c:\Users\dell\anaconda3\lib\site-packages\pandas\io\parsers\readers.py", line 586, in read_csv
#     return _read(filepath_or_buffer, kwds)
#   File "c:\Users\dell\anaconda3\lib\site-packages\pandas\io\parsers\readers.py", line 482, in _read
#     parser = TextFileReader(filepath_or_buffer, **kwds)
#   File "c:\Users\dell\anaconda3\lib\site-packages\pandas\io\parsers\readers.py", line 811, in __init__
#     self._engine = self._make_engine(self.engine)
#   File "c:\Users\dell\anaconda3\lib\site-packages\pandas\io\parsers\readers.py", line 1040, in _make_engine
#     return mapping[engine](self.f, **self.options)  # type: ignore[call-arg]
#   File "c:\Users\dell\anaconda3\lib\site-packages\pandas\io\parsers\c_parser_wrapper.py", line 69, in __init__
#     self._reader = parsers.TextReader(self.handles.handle, **kwds)
#   File "pandas\_libs\parsers.pyx", line 549, in pandas._libs.parsers.TextReader.__cinit__
# pandas.errors.EmptyDataError: No columns to parse from file
# Traceback (most recent call last):
#   File "C:\Users\dell\AppData\Local\Temp/ipykernel_24380/1587361920.py", line 7, in <module>
#     df_row = get_year_data(file_path)
#   File "C:\Users\dell\AppData\Local\Temp/ipykernel_24380/1014522285.py", line 7, in get_year_data
#     data = pd.read_csv(file_path)
#   File "c:\Users\dell\anaconda3\lib\site-packages\pandas\util\_decorators.py", line 311, in wrapper
#     return func(*args, **kwargs)
#   File "c:\Users\dell\anaconda3\lib\site-packages\pandas\io\parsers\readers.py", line 586, in read_csv
#     return _read(filepath_or_buffer, kwds)
#   File "c:\Users\dell\anaconda3\lib\site-packages\pandas\io\parsers\readers.py", line 482, in _read
#     parser = TextFileReader(filepath_or_buffer, **kwds)
#   File "c:\Users\dell\anaconda3\lib\site-packages\pandas\io\parsers\readers.py", line 811, in __init__
#     self._engine = self._make_engine(self.engine)
#   File "c:\Users\dell\anaconda3\lib\site-packages\pandas\io\parsers\readers.py", line 1040, in _make_engine
#     return mapping[engine](self.f, **self.options)  # type: ignore[call-arg]
#   File "c:\Users\dell\anaconda3\lib\site-packages\pandas\io\parsers\c_parser_wrapper.py", line 69, in __init__
#     self._reader = parsers.TextReader(self.handles.handle, **kwds)
#   File "pandas\_libs\parsers.pyx", line 549, in pandas._libs.parsers.TextReader.__cinit__
# pandas.errors.EmptyDataError: No columns to parse from file
# Traceback (most recent call last):
#   File "C:\Users\dell\AppData\Local\Temp/ipykernel_24380/1587361920.py", line 7, in <module>
#     df_row = get_year_data(file_path)
#   File "C:\Users\dell\AppData\Local\Temp/ipykernel_24380/1014522285.py", line 7, in get_year_data
#     data = pd.read_csv(file_path)
#   File "c:\Users\dell\anaconda3\lib\site-packages\pandas\util\_decorators.py", line 311, in wrapper
#     return func(*args, **kwargs)
#   File "c:\Users\dell\anaconda3\lib\site-packages\pandas\io\parsers\readers.py", line 586, in read_csv
#     return _read(filepath_or_buffer, kwds)
#   File "c:\Users\dell\anaconda3\lib\site-packages\pandas\io\parsers\readers.py", line 482, in _read
#     parser = TextFileReader(filepath_or_buffer, **kwds)
#   File "c:\Users\dell\anaconda3\lib\site-packages\pandas\io\parsers\readers.py", line 811, in __init__
#     self._engine = self._make_engine(self.engine)
#   File "c:\Users\dell\anaconda3\lib\site-packages\pandas\io\parsers\readers.py", line 1040, in _make_engine
#     return mapping[engine](self.f, **self.options)  # type: ignore[call-arg]
#   File "c:\Users\dell\anaconda3\lib\site-packages\pandas\io\parsers\c_parser_wrapper.py", line 69, in __init__
#     self._reader = parsers.TextReader(self.handles.handle, **kwds)
#   File "pandas\_libs\parsers.pyx", line 549, in pandas._libs.parsers.TextReader.__cinit__
# pandas.errors.EmptyDataError: No columns to parse from file
# Error processing '../Data/CleanData/HepatitisE_rate.csv': No columns to parse from file
# Error processing '../Data/CleanData/HFM_rate.csv': No columns to parse from file
# Error processing '../Data/CleanData/Influenza_rate.csv': No columns to parse from file
# Error processing '../Data/CleanData/Japanese B encephalitis_rate.csv': No columns to parse from file
# Traceback (most recent call last):
#   File "C:\Users\dell\AppData\Local\Temp/ipykernel_24380/1587361920.py", line 7, in <module>
#     df_row = get_year_data(file_path)
#   File "C:\Users\dell\AppData\Local\Temp/ipykernel_24380/1014522285.py", line 7, in get_year_data
#     data = pd.read_csv(file_path)
#   File "c:\Users\dell\anaconda3\lib\site-packages\pandas\util\_decorators.py", line 311, in wrapper
#     return func(*args, **kwargs)
#   File "c:\Users\dell\anaconda3\lib\site-packages\pandas\io\parsers\readers.py", line 586, in read_csv
#     return _read(filepath_or_buffer, kwds)
#   File "c:\Users\dell\anaconda3\lib\site-packages\pandas\io\parsers\readers.py", line 482, in _read
#     parser = TextFileReader(filepath_or_buffer, **kwds)
#   File "c:\Users\dell\anaconda3\lib\site-packages\pandas\io\parsers\readers.py", line 811, in __init__
#     self._engine = self._make_engine(self.engine)
#   File "c:\Users\dell\anaconda3\lib\site-packages\pandas\io\parsers\readers.py", line 1040, in _make_engine
#     return mapping[engine](self.f, **self.options)  # type: ignore[call-arg]
#   File "c:\Users\dell\anaconda3\lib\site-packages\pandas\io\parsers\c_parser_wrapper.py", line 69, in __init__
#     self._reader = parsers.TextReader(self.handles.handle, **kwds)
#   File "pandas\_libs\parsers.pyx", line 549, in pandas._libs.parsers.TextReader.__cinit__
# pandas.errors.EmptyDataError: No columns to parse from file
# Traceback (most recent call last):
#   File "C:\Users\dell\AppData\Local\Temp/ipykernel_24380/1587361920.py", line 7, in <module>
#     df_row = get_year_data(file_path)
#   File "C:\Users\dell\AppData\Local\Temp/ipykernel_24380/1014522285.py", line 7, in get_year_data
#     data = pd.read_csv(file_path)
#   File "c:\Users\dell\anaconda3\lib\site-packages\pandas\util\_decorators.py", line 311, in wrapper
#     return func(*args, **kwargs)
#   File "c:\Users\dell\anaconda3\lib\site-packages\pandas\io\parsers\readers.py", line 586, in read_csv
#     return _read(filepath_or_buffer, kwds)
#   File "c:\Users\dell\anaconda3\lib\site-packages\pandas\io\parsers\readers.py", line 482, in _read
#     parser = TextFileReader(filepath_or_buffer, **kwds)
#   File "c:\Users\dell\anaconda3\lib\site-packages\pandas\io\parsers\readers.py", line 811, in __init__
#     self._engine = self._make_engine(self.engine)
#   File "c:\Users\dell\anaconda3\lib\site-packages\pandas\io\parsers\readers.py", line 1040, in _make_engine
#     return mapping[engine](self.f, **self.options)  # type: ignore[call-arg]
#   File "c:\Users\dell\anaconda3\lib\site-packages\pandas\io\parsers\c_parser_wrapper.py", line 69, in __init__
#     self._reader = parsers.TextReader(self.handles.handle, **kwds)
#   File "pandas\_libs\parsers.pyx", line 549, in pandas._libs.parsers.TextReader.__cinit__
# pandas.errors.EmptyDataError: No columns to parse from file
# Traceback (most recent call last):
#   File "C:\Users\dell\AppData\Local\Temp/ipykernel_24380/1587361920.py", line 7, in <module>
#     df_row = get_year_data(file_path)
#   File "C:\Users\dell\AppData\Local\Temp/ipykernel_24380/1014522285.py", line 7, in get_year_data
#     data = pd.read_csv(file_path)
#   File "c:\Users\dell\anaconda3\lib\site-packages\pandas\util\_decorators.py", line 311, in wrapper
#     return func(*args, **kwargs)
#   File "c:\Users\dell\anaconda3\lib\site-packages\pandas\io\parsers\readers.py", line 586, in read_csv
#     return _read(filepath_or_buffer, kwds)
#   File "c:\Users\dell\anaconda3\lib\site-packages\pandas\io\parsers\readers.py", line 482, in _read
#     parser = TextFileReader(filepath_or_buffer, **kwds)
#   File "c:\Users\dell\anaconda3\lib\site-packages\pandas\io\parsers\readers.py", line 811, in __init__
#     self._engine = self._make_engine(self.engine)
#   File "c:\Users\dell\anaconda3\lib\site-packages\pandas\io\parsers\readers.py", line 1040, in _make_engine
#     return mapping[engine](self.f, **self.options)  # type: ignore[call-arg]
#   File "c:\Users\dell\anaconda3\lib\site-packages\pandas\io\parsers\c_parser_wrapper.py", line 69, in __init__
#     self._reader = parsers.TextReader(self.handles.handle, **kwds)
#   File "pandas\_libs\parsers.pyx", line 549, in pandas._libs.parsers.TextReader.__cinit__
# pandas.errors.EmptyDataError: No columns to parse from file
# Traceback (most recent call last):
#   File "C:\Users\dell\AppData\Local\Temp/ipykernel_24380/1587361920.py", line 7, in <module>
#     df_row = get_year_data(file_path)
#   File "C:\Users\dell\AppData\Local\Temp/ipykernel_24380/1014522285.py", line 7, in get_year_data
#     data = pd.read_csv(file_path)
#   File "c:\Users\dell\anaconda3\lib\site-packages\pandas\util\_decorators.py", line 311, in wrapper
#     return func(*args, **kwargs)
#   File "c:\Users\dell\anaconda3\lib\site-packages\pandas\io\parsers\readers.py", line 586, in read_csv
#     return _read(filepath_or_buffer, kwds)
#   File "c:\Users\dell\anaconda3\lib\site-packages\pandas\io\parsers\readers.py", line 482, in _read
#     parser = TextFileReader(filepath_or_buffer, **kwds)
#   File "c:\Users\dell\anaconda3\lib\site-packages\pandas\io\parsers\readers.py", line 811, in __init__
#     self._engine = self._make_engine(self.engine)
#   File "c:\Users\dell\anaconda3\lib\site-packages\pandas\io\parsers\readers.py", line 1040, in _make_engine
#     return mapping[engine](self.f, **self.options)  # type: ignore[call-arg]
#   File "c:\Users\dell\anaconda3\lib\site-packages\pandas\io\parsers\c_parser_wrapper.py", line 69, in __init__
#     self._reader = parsers.TextReader(self.handles.handle, **kwds)
#   File "pandas\_libs\parsers.pyx", line 549, in pandas._libs.parsers.TextReader.__cinit__
# pandas.errors.EmptyDataError: No columns to parse from file
# Error processing '../Data/CleanData/Kala azar_rate.csv': No columns to parse from file
# Error processing '../Data/CleanData/L.G.V.&other&unsp.V.D_rate.csv': No columns to parse from file
# Error processing '../Data/CleanData/Leprosy_rate.csv': No columns to parse from file
# Error processing '../Data/CleanData/Leptospirosis_rate.csv': No columns to parse from file
# Traceback (most recent call last):
# ...
#     return func(*args, **kwargs)
#   File "c:\Users\dell\anaconda3\lib\site-packages\pandas\io\parsers\readers.py", line 586, in read_csv
#     return _read(filepath_or_buffer, kwds)
#   File "c:\Users\dell\anaconda3\lib\site-packages\pandas\io\parsers\readers.py", line 482, in _read
#     parser = TextFileReader(filepath_or_buffer, **kwds)
#   File "c:\Users\dell\anaconda3\lib\site-packages\pandas\io\parsers\readers.py", line 811, in __init__
#     self._engine = self._make_engine(self.engine)
#   File "c:\Users\dell\anaconda3\lib\site-packages\pandas\io\parsers\readers.py", line 1040, in _make_engine
#     return mapping[engine](self.f, **self.options)  # type: ignore[call-arg]
#   File "c:\Users\dell\anaconda3\lib\site-packages\pandas\io\parsers\c_parser_wrapper.py", line 69, in __init__
#     self._reader = parsers.TextReader(self.handles.handle, **kwds)
#   File "pandas\_libs\parsers.pyx", line 549, in pandas._libs.parsers.TextReader.__cinit__
# pandas.errors.EmptyDataError: No columns to parse from file
# Traceback (most recent call last):
#   File "C:\Users\dell\AppData\Local\Temp/ipykernel_24380/1587361920.py", line 7, in <module>
#     df_row = get_year_data(file_path)
#   File "C:\Users\dell\AppData\Local\Temp/ipykernel_24380/1014522285.py", line 7, in get_year_data
#     data = pd.read_csv(file_path)
#   File "c:\Users\dell\anaconda3\lib\site-packages\pandas\util\_decorators.py", line 311, in wrapper
#     return func(*args, **kwargs)
#   File "c:\Users\dell\anaconda3\lib\site-packages\pandas\io\parsers\readers.py", line 586, in read_csv
#     return _read(filepath_or_buffer, kwds)
#   File "c:\Users\dell\anaconda3\lib\site-packages\pandas\io\parsers\readers.py", line 482, in _read
#     parser = TextFileReader(filepath_or_buffer, **kwds)
#   File "c:\Users\dell\anaconda3\lib\site-packages\pandas\io\parsers\readers.py", line 811, in __init__
#     self._engine = self._make_engine(self.engine)
#   File "c:\Users\dell\anaconda3\lib\site-packages\pandas\io\parsers\readers.py", line 1040, in _make_engine
#     return mapping[engine](self.f, **self.options)  # type: ignore[call-arg]
#   File "c:\Users\dell\anaconda3\lib\site-packages\pandas\io\parsers\c_parser_wrapper.py", line 69, in __init__
#     self._reader = parsers.TextReader(self.handles.handle, **kwds)
#   File "pandas\_libs\parsers.pyx", line 549, in pandas._libs.parsers.TextReader.__cinit__
# pandas.errors.EmptyDataError: No columns to parse from file
# Error processing '../Data/CleanData/Streptococcus suis_rate.csv': No columns to parse from file
# Error processing '../Data/CleanData/Syphilis_rate.csv': No columns to parse from file
# Error processing '../Data/CleanData/T.B. other organs_rate.csv': No columns to parse from file
# Error processing '../Data/CleanData/T.B.meningitis_rate.csv': No columns to parse from file
# Traceback (most recent call last):
#   File "C:\Users\dell\AppData\Local\Temp/ipykernel_24380/1587361920.py", line 7, in <module>
#     df_row = get_year_data(file_path)
#   File "C:\Users\dell\AppData\Local\Temp/ipykernel_24380/1014522285.py", line 7, in get_year_data
#     data = pd.read_csv(file_path)
#   File "c:\Users\dell\anaconda3\lib\site-packages\pandas\util\_decorators.py", line 311, in wrapper
#     return func(*args, **kwargs)
#   File "c:\Users\dell\anaconda3\lib\site-packages\pandas\io\parsers\readers.py", line 586, in read_csv
#     return _read(filepath_or_buffer, kwds)
#   File "c:\Users\dell\anaconda3\lib\site-packages\pandas\io\parsers\readers.py", line 482, in _read
#     parser = TextFileReader(filepath_or_buffer, **kwds)
#   File "c:\Users\dell\anaconda3\lib\site-packages\pandas\io\parsers\readers.py", line 811, in __init__
#     self._engine = self._make_engine(self.engine)
#   File "c:\Users\dell\anaconda3\lib\site-packages\pandas\io\parsers\readers.py", line 1040, in _make_engine
#     return mapping[engine](self.f, **self.options)  # type: ignore[call-arg]
#   File "c:\Users\dell\anaconda3\lib\site-packages\pandas\io\parsers\c_parser_wrapper.py", line 69, in __init__
#     self._reader = parsers.TextReader(self.handles.handle, **kwds)
#   File "pandas\_libs\parsers.pyx", line 549, in pandas._libs.parsers.TextReader.__cinit__
# pandas.errors.EmptyDataError: No columns to parse from file
# Traceback (most recent call last):
#   File "C:\Users\dell\AppData\Local\Temp/ipykernel_24380/1587361920.py", line 7, in <module>
#     df_row = get_year_data(file_path)
#   File "C:\Users\dell\AppData\Local\Temp/ipykernel_24380/1014522285.py", line 7, in get_year_data
#     data = pd.read_csv(file_path)
#   File "c:\Users\dell\anaconda3\lib\site-packages\pandas\util\_decorators.py", line 311, in wrapper
#     return func(*args, **kwargs)
#   File "c:\Users\dell\anaconda3\lib\site-packages\pandas\io\parsers\readers.py", line 586, in read_csv
#     return _read(filepath_or_buffer, kwds)
#   File "c:\Users\dell\anaconda3\lib\site-packages\pandas\io\parsers\readers.py", line 482, in _read
#     parser = TextFileReader(filepath_or_buffer, **kwds)
#   File "c:\Users\dell\anaconda3\lib\site-packages\pandas\io\parsers\readers.py", line 811, in __init__
#     self._engine = self._make_engine(self.engine)
#   File "c:\Users\dell\anaconda3\lib\site-packages\pandas\io\parsers\readers.py", line 1040, in _make_engine
#     return mapping[engine](self.f, **self.options)  # type: ignore[call-arg]
#   File "c:\Users\dell\anaconda3\lib\site-packages\pandas\io\parsers\c_parser_wrapper.py", line 69, in __init__
#     self._reader = parsers.TextReader(self.handles.handle, **kwds)
#   File "pandas\_libs\parsers.pyx", line 549, in pandas._libs.parsers.TextReader.__cinit__
# pandas.errors.EmptyDataError: No columns to parse from file
# Traceback (most recent call last):
#   File "C:\Users\dell\AppData\Local\Temp/ipykernel_24380/1587361920.py", line 7, in <module>
#     df_row = get_year_data(file_path)
#   File "C:\Users\dell\AppData\Local\Temp/ipykernel_24380/1014522285.py", line 7, in get_year_data
#     data = pd.read_csv(file_path)
#   File "c:\Users\dell\anaconda3\lib\site-packages\pandas\util\_decorators.py", line 311, in wrapper
#     return func(*args, **kwargs)
#   File "c:\Users\dell\anaconda3\lib\site-packages\pandas\io\parsers\readers.py", line 586, in read_csv
#     return _read(filepath_or_buffer, kwds)
#   File "c:\Users\dell\anaconda3\lib\site-packages\pandas\io\parsers\readers.py", line 482, in _read
#     parser = TextFileReader(filepath_or_buffer, **kwds)
#   File "c:\Users\dell\anaconda3\lib\site-packages\pandas\io\parsers\readers.py", line 811, in __init__
#     self._engine = self._make_engine(self.engine)
#   File "c:\Users\dell\anaconda3\lib\site-packages\pandas\io\parsers\readers.py", line 1040, in _make_engine
#     return mapping[engine](self.f, **self.options)  # type: ignore[call-arg]
#   File "c:\Users\dell\anaconda3\lib\site-packages\pandas\io\parsers\c_parser_wrapper.py", line 69, in __init__
#     self._reader = parsers.TextReader(self.handles.handle, **kwds)
#   File "pandas\_libs\parsers.pyx", line 549, in pandas._libs.parsers.TextReader.__cinit__
# pandas.errors.EmptyDataError: No columns to parse from file
# Error processing '../Data/CleanData/Tetanus exc.Neo_rate.csv': No columns to parse from file
# Error processing '../Data/CleanData/Tetanus neonatorum_rate.csv': No columns to parse from file
# Error processing '../Data/CleanData/Trichinosis_rate.csv': No columns to parse from file
# Error processing '../Data/CleanData/Typhoid_rate.csv': No columns to parse from file
# Error processing '../Data/CleanData/Vaginal trichomoniasis_rate.csv': No columns to parse from file
# Traceback (most recent call last):
#   File "C:\Users\dell\AppData\Local\Temp/ipykernel_24380/1587361920.py", line 7, in <module>
#     df_row = get_year_data(file_path)
#   File "C:\Users\dell\AppData\Local\Temp/ipykernel_24380/1014522285.py", line 7, in get_year_data
#     data = pd.read_csv(file_path)
#   File "c:\Users\dell\anaconda3\lib\site-packages\pandas\util\_decorators.py", line 311, in wrapper
#     return func(*args, **kwargs)
#   File "c:\Users\dell\anaconda3\lib\site-packages\pandas\io\parsers\readers.py", line 586, in read_csv
#     return _read(filepath_or_buffer, kwds)
#   File "c:\Users\dell\anaconda3\lib\site-packages\pandas\io\parsers\readers.py", line 482, in _read
#     parser = TextFileReader(filepath_or_buffer, **kwds)
#   File "c:\Users\dell\anaconda3\lib\site-packages\pandas\io\parsers\readers.py", line 811, in __init__
#     self._engine = self._make_engine(self.engine)
#   File "c:\Users\dell\anaconda3\lib\site-packages\pandas\io\parsers\readers.py", line 1040, in _make_engine
#     return mapping[engine](self.f, **self.options)  # type: ignore[call-arg]
#   File "c:\Users\dell\anaconda3\lib\site-packages\pandas\io\parsers\c_parser_wrapper.py", line 69, in __init__
#     self._reader = parsers.TextReader(self.handles.handle, **kwds)
#   File "pandas\_libs\parsers.pyx", line 549, in pandas._libs.parsers.TextReader.__cinit__
# pandas.errors.EmptyDataError: No columns to parse from file
# Traceback (most recent call last):
#   File "C:\Users\dell\AppData\Local\Temp/ipykernel_24380/1587361920.py", line 7, in <module>
#     df_row = get_year_data(file_path)
#   File "C:\Users\dell\AppData\Local\Temp/ipykernel_24380/1014522285.py", line 7, in get_year_data
#     data = pd.read_csv(file_path)
#   File "c:\Users\dell\anaconda3\lib\site-packages\pandas\util\_decorators.py", line 311, in wrapper
#     return func(*args, **kwargs)
#   File "c:\Users\dell\anaconda3\lib\site-packages\pandas\io\parsers\readers.py", line 586, in read_csv
#     return _read(filepath_or_buffer, kwds)
#   File "c:\Users\dell\anaconda3\lib\site-packages\pandas\io\parsers\readers.py", line 482, in _read
#     parser = TextFileReader(filepath_or_buffer, **kwds)
#   File "c:\Users\dell\anaconda3\lib\site-packages\pandas\io\parsers\readers.py", line 811, in __init__
#     self._engine = self._make_engine(self.engine)
#   File "c:\Users\dell\anaconda3\lib\site-packages\pandas\io\parsers\readers.py", line 1040, in _make_engine
#     return mapping[engine](self.f, **self.options)  # type: ignore[call-arg]
#   File "c:\Users\dell\anaconda3\lib\site-packages\pandas\io\parsers\c_parser_wrapper.py", line 69, in __init__
#     self._reader = parsers.TextReader(self.handles.handle, **kwds)
#   File "pandas\_libs\parsers.pyx", line 549, in pandas._libs.parsers.TextReader.__cinit__
# pandas.errors.EmptyDataError: No columns to parse from file
# Traceback (most recent call last):
#   File "C:\Users\dell\AppData\Local\Temp/ipykernel_24380/1587361920.py", line 7, in <module>
#     df_row = get_year_data(file_path)
#   File "C:\Users\dell\AppData\Local\Temp/ipykernel_24380/1014522285.py", line 7, in get_year_data
#     data = pd.read_csv(file_path)
#   File "c:\Users\dell\anaconda3\lib\site-packages\pandas\util\_decorators.py", line 311, in wrapper
#     return func(*args, **kwargs)
#   File "c:\Users\dell\anaconda3\lib\site-packages\pandas\io\parsers\readers.py", line 586, in read_csv
#     return _read(filepath_or_buffer, kwds)
#   File "c:\Users\dell\anaconda3\lib\site-packages\pandas\io\parsers\readers.py", line 482, in _read
#     parser = TextFileReader(filepath_or_buffer, **kwds)
#   File "c:\Users\dell\anaconda3\lib\site-packages\pandas\io\parsers\readers.py", line 811, in __init__
#     self._engine = self._make_engine(self.engine)
#   File "c:\Users\dell\anaconda3\lib\site-packages\pandas\io\parsers\readers.py", line 1040, in _make_engine
#     return mapping[engine](self.f, **self.options)  # type: ignore[call-arg]
#   File "c:\Users\dell\anaconda3\lib\site-packages\pandas\io\parsers\c_parser_wrapper.py", line 69, in __init__
#     self._reader = parsers.TextReader(self.handles.handle, **kwds)
#   File "pandas\_libs\parsers.pyx", line 549, in pandas._libs.parsers.TextReader.__cinit__
# pandas.errors.EmptyDataError: No columns to parse from file
# Traceback (most recent call last):
#   File "C:\Users\dell\AppData\Local\Temp/ipykernel_24380/1587361920.py", line 7, in <module>
#     df_row = get_year_data(file_path)
#   File "C:\Users\dell\AppData\Local\Temp/ipykernel_24380/1014522285.py", line 7, in get_year_data
#     data = pd.read_csv(file_path)
#   File "c:\Users\dell\anaconda3\lib\site-packages\pandas\util\_decorators.py", line 311, in wrapper
#     return func(*args, **kwargs)
#   File "c:\Users\dell\anaconda3\lib\site-packages\pandas\io\parsers\readers.py", line 586, in read_csv
#     return _read(filepath_or_buffer, kwds)
#   File "c:\Users\dell\anaconda3\lib\site-packages\pandas\io\parsers\readers.py", line 482, in _read
#     parser = TextFileReader(filepath_or_buffer, **kwds)
#   File "c:\Users\dell\anaconda3\lib\site-packages\pandas\io\parsers\readers.py", line 811, in __init__
#     self._engine = self._make_engine(self.engine)
#   File "c:\Users\dell\anaconda3\lib\site-packages\pandas\io\parsers\readers.py", line 1040, in _make_engine
#     return mapping[engine](self.f, **self.options)  # type: ignore[call-arg]
#   File "c:\Users\dell\anaconda3\lib\site-packages\pandas\io\parsers\c_parser_wrapper.py", line 69, in __init__
#     self._reader = parsers.TextReader(self.handles.handle, **kwds)
#   File "pandas\_libs\parsers.pyx", line 549, in pandas._libs.parsers.TextReader.__cinit__
# pandas.errors.EmptyDataError: No columns to parse from file
# Error processing '../Data/CleanData/Zika virus_rate.csv': No columns to parse from file
# Saved result to ../Data/GetData.csv, rows=201
# Traceback (most recent call last):
#   File "C:\Users\dell\AppData\Local\Temp/ipykernel_24380/1587361920.py", line 7, in <module>
#     df_row = get_year_data(file_path)
#   File "C:\Users\dell\AppData\Local\Temp/ipykernel_24380/1014522285.py", line 7, in get_year_data
#     data = pd.read_csv(file_path)
#   File "c:\Users\dell\anaconda3\lib\site-packages\pandas\util\_decorators.py", line 311, in wrapper
#     return func(*args, **kwargs)
#   File "c:\Users\dell\anaconda3\lib\site-packages\pandas\io\parsers\readers.py", line 586, in read_csv
#     return _read(filepath_or_buffer, kwds)
#   File "c:\Users\dell\anaconda3\lib\site-packages\pandas\io\parsers\readers.py", line 482, in _read
#     parser = TextFileReader(filepath_or_buffer, **kwds)
#   File "c:\Users\dell\anaconda3\lib\site-packages\pandas\io\parsers\readers.py", line 811, in __init__
#     self._engine = self._make_engine(self.engine)
#   File "c:\Users\dell\anaconda3\lib\site-packages\pandas\io\parsers\readers.py", line 1040, in _make_engine
#     return mapping[engine](self.f, **self.options)  # type: ignore[call-arg]
#   File "c:\Users\dell\anaconda3\lib\site-packages\pandas\io\parsers\c_parser_wrapper.py", line 69, in __init__
#     self._reader = parsers.TextReader(self.handles.handle, **kwds)
#   File "pandas\_libs\parsers.pyx", line 549, in pandas._libs.parsers.TextReader.__cinit__
# pandas.errors.EmptyDataError: No columns to parse from file
# Traceback (most recent call last):
#   File "C:\Users\dell\AppData\Local\Temp/ipykernel_24380/1587361920.py", line 7, in <module>
#     df_row = get_year_data(file_path)
#   File "C:\Users\dell\AppData\Local\Temp/ipykernel_24380/1014522285.py", line 7, in get_year_data
#     data = pd.read_csv(file_path)
#   File "c:\Users\dell\anaconda3\lib\site-packages\pandas\util\_decorators.py", line 311, in wrapper
#     return func(*args, **kwargs)
#   File "c:\Users\dell\anaconda3\lib\site-packages\pandas\io\parsers\readers.py", line 586, in read_csv
#     return _read(filepath_or_buffer, kwds)
#   File "c:\Users\dell\anaconda3\lib\site-packages\pandas\io\parsers\readers.py", line 482, in _read
#     parser = TextFileReader(filepath_or_buffer, **kwds)
#   File "c:\Users\dell\anaconda3\lib\site-packages\pandas\io\parsers\readers.py", line 811, in __init__
#     self._engine = self._make_engine(self.engine)
#   File "c:\Users\dell\anaconda3\lib\site-packages\pandas\io\parsers\readers.py", line 1040, in _make_engine
#     return mapping[engine](self.f, **self.options)  # type: ignore[call-arg]
#   File "c:\Users\dell\anaconda3\lib\site-packages\pandas\io\parsers\c_parser_wrapper.py", line 69, in __init__
#     self._reader = parsers.TextReader(self.handles.handle, **kwds)
#   File "pandas\_libs\parsers.pyx", line 549, in pandas._libs.parsers.TextReader.__cinit__
# pandas.errors.EmptyDataError: No columns to parse from file
